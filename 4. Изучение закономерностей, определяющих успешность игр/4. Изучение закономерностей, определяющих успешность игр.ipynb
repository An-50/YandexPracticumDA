# %% [markdown]
# # 4. Изучение закономерностей, определяющих успешность игр

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Открываем-файл-с-данными-и-изучаем-общую-информацию" data-toc-modified-id="Открываем-файл-с-данными-и-изучаем-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открываем файл с данными и изучаем общую информацию</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Загружаем-данные" data-toc-modified-id="Загружаем-данные-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загружаем данные</a></span></li><li><span><a href="#смотрим-информацию" data-toc-modified-id="смотрим-информацию-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>смотрим информацию</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Названия-столбцов-приводим-к-нижнему-регистру" data-toc-modified-id="Названия-столбцов-приводим-к-нижнему-регистру-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Названия столбцов приводим к нижнему регистру</a></span></li><li><span><a href="#Преобразуем-данные-в-нужные-типы" data-toc-modified-id="Преобразуем-данные-в-нужные-типы-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Преобразуем данные в нужные типы</a></span><ul class="toc-item"><li><span><a href="#Меняем-тип-данных-в-столбце-'year_of_release'" data-toc-modified-id="Меняем-тип-данных-в-столбце-'year_of_release'-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Меняем тип данных в столбце 'year_of_release'</a></span></li><li><span><a href="#Меняем-тип-данных-в-столбце-'user_score'" data-toc-modified-id="Меняем-тип-данных-в-столбце-'user_score'-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Меняем тип данных в столбце 'user_score'</a></span></li></ul></li><li><span><a href="#Обрабатываем-пропуски" data-toc-modified-id="Обрабатываем-пропуски-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обрабатываем пропуски</a></span><ul class="toc-item"><li><span><a href="#Пропуски-в-столбце-'name'" data-toc-modified-id="Пропуски-в-столбце-'name'-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Пропуски в столбце 'name'</a></span></li><li><span><a href="#Пропуски-в-столбце-'year_of_release'" data-toc-modified-id="Пропуски-в-столбце-'year_of_release'-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Пропуски в столбце 'year_of_release'</a></span></li><li><span><a href="#Пропуски-в-столбце-'genre'" data-toc-modified-id="Пропуски-в-столбце-'genre'-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Пропуски в столбце 'genre'</a></span></li><li><span><a href="#Пропуски-в-столбцах-'critic_score'-и-'user_score'" data-toc-modified-id="Пропуски-в-столбцах-'critic_score'-и-'user_score'-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Пропуски в столбцах 'critic_score' и 'user_score'</a></span></li><li><span><a href="#Пропуски-в-столбце-'rating'" data-toc-modified-id="Пропуски-в-столбце-'rating'-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Пропуски в столбце 'rating'</a></span></li></ul></li><li><span><a href="#Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-столбец-'total_sales'" data-toc-modified-id="Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-столбец-'total_sales'-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Посчитаем суммарные продажи во всех регионах и запишем их в столбец 'total_sales'</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрим,-сколько-игр-выпускалось-в-разные-годы" data-toc-modified-id="Посмотрим,-сколько-игр-выпускалось-в-разные-годы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотрим, сколько игр выпускалось в разные годы</a></span></li><li><span><a href="#Продажи-по-платформам" data-toc-modified-id="Продажи-по-платформам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Продажи по платформам</a></span></li><li><span><a href="#Динамика-продаж" data-toc-modified-id="Динамика-продаж-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Динамика продаж</a></span></li><li><span><a href="#График-«ящик-с-усами»-по-глобальным-продажам-игр" data-toc-modified-id="График-«ящик-с-усами»-по-глобальным-продажам-игр-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>График «ящик с усами» по глобальным продажам игр</a></span></li><li><span><a href="#Влияние-отзывов-пользователей-и-критиков--на-продажи" data-toc-modified-id="Влияние-отзывов-пользователей-и-критиков--на-продажи-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Влияние отзывов пользователей и критиков  на продажи</a></span><ul class="toc-item"><li><span><a href="#Влияние-отзывов-критиков-на-продажи" data-toc-modified-id="Влияние-отзывов-критиков-на-продажи-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Влияние отзывов критиков на продажи</a></span></li><li><span><a href="#Влияние-отзывов-пользователей-на-продажи" data-toc-modified-id="Влияние-отзывов-пользователей-на-продажи-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Влияние отзывов пользователей на продажи</a></span></li><li><span><a href="#Посмотрим--корреляцию-между-отзывами-и-продажами" data-toc-modified-id="Посмотрим--корреляцию-между-отзывами-и-продажами-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Посмотрим  корреляцию между отзывами и продажами</a></span></li></ul></li><li><span><a href="#Общее-распределение-игр-по-жанрам" data-toc-modified-id="Общее-распределение-игр-по-жанрам-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Общее распределение игр по жанрам</a></span></li></ul></li><li><span><a href="#Составляем-портрет-пользователя-каждого-региона" data-toc-modified-id="Составляем-портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составляем портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5)" data-toc-modified-id="Самые-популярные-платформы-(топ-5)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Самые популярные платформы (топ-5)</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5)" data-toc-modified-id="Самые-популярные-жанры-(топ-5)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5)</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи</a></span></li></ul></li><li><span><a href="#Проверяем-гипотезы" data-toc-modified-id="Проверяем-гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверяем гипотезы</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные." data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# # Описание данных
#
# * **Name** — название игры
# * **Platform** — платформа
# * **Year_of_Release** — год выпуска
# * **Genre** — жанр игры
# * **NA_sales** — продажи в Северной Америке (миллионы проданных копий)
# * **EU_sales** — продажи в Европе (миллионы проданных копий)
# * **JP_sales** — продажи в Японии (миллионы проданных копий)
# * **Other_sales** — продажи в других странах (миллионы проданных копий)
# * **Critic_Score** — оценка критиков (максимум 100)
# * **User_Score** — оценка пользователей (максимум 10)
# * **Rating** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ESRB была основана в 1994 году
#
# Рейтинг игр ESRB основан на их содержании аналогично рейтинговым системам кинофильмов. Рейтинг игры напечатан на упаковке, содержится в её рекламе и указан на сайте игры.
#
# * «EC» («Early childhood») — «Для детей младшего возраста»
# * «E» («Everyone») — «Для всех»
# * «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# * «T» («Teen») — «Подросткам»
# * «M» («Mature») — «Для взрослых»
# * «AO» («Adults Only 18+») — «Только для взрослых»
# * «RP» («Rating Pending») — «Рейтинг ожидается»
#
# *https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board*

# %% [markdown]
# ## Открываем файл с данными и изучаем общую информацию

# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats as st
# %matplotlib inline

pd.set_option('display.max_columns', 50) #устанавливаем максимальное число отображаемых колонок
pd.set_option('display.max_rows', 100)

def load_csv_choose_path(file):
    if os.path.exists(file):
        db = pd.read_csv(file)
    elif os.path.exists('/datasets/'+file):
        db = pd.read_csv('/datasets/'+file)
    else:
        raise FileNotFoundError(file)
    return db

# %% [markdown]
# ### Загружаем данные

# %%
games = load_csv_choose_path('games.csv')

# %% [markdown]
# ### смотрим информацию

# %%
games.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# Имеются пропуски

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# * Замените названия столбцов (приведите к нижнему регистру);
# * Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработайте пропуски при необходимости:
#     * Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#     * Опишите причины, которые могли привести к пропускам;
#     * Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать;
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %% [markdown]
# ### Названия столбцов приводим к нижнему регистру

# %%
games.columns = games.columns.str.lower()

# %% [markdown]
# ### Преобразуем данные в нужные типы
# #### Меняем тип данных в столбце 'year_of_release'

# %%
games['year_of_release'] = pd.to_datetime(games['year_of_release'], format='%Y')

# %% [markdown]
# #### Меняем тип данных в столбце 'user_score'

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
games[games['user_score'] == 'tbd']
# Out:
#                                            name platform year_of_release  \
# 119                               Zumba Fitness      Wii      2010-01-01
# 301              Namco Museum: 50th Anniversary      PS2      2005-01-01
# 520                             Zumba Fitness 2      Wii      2011-01-01
# 645                                uDraw Studio      Wii      2010-01-01
# 657    Frogger's Adventures: Temple of the Frog      GBA             NaT
# ...                                         ...      ...             ...
# 16695                           Planet Monsters      GBA      2001-01-01
# 16697                          Bust-A-Move 3000       GC      2003-01-01
# 16698                          Mega Brain Boost       DS      2008-01-01
# 16704                                  Plushees       DS      2008-01-01
# 16706             Men in Black II: Alien Escape       GC      2003-01-01
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# 'tbd' не дает привести столбец к 'float'. tbd (to be determined), то есть "Будет определено", насколько я понимаю, что рейтинг отсутсвует. Поэтому я думаю, что можно заменить tbd на NaN и поменяем тип данных.

# %%
games['user_score'] = games['user_score'].replace('tbd', np.NaN).astype('float')

# %% [markdown]
# ### Обрабатываем пропуски

# %%
games.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %% [markdown]
# #### Пропуски в столбце 'name'

# %%
games[games['name'].isna()]
# Out:
#       name platform year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN      1993-01-01   NaN      1.78      0.53      0.00
# 14244  NaN      GEN      1993-01-01   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %% [markdown]
# У игр без имени есть продажи, оставим эти строки, заменим имя на "NoName"

# %%
games['name'].fillna('NoName', inplace=True)

# %% [markdown]
# #### Пропуски в столбце 'year_of_release'
# Пропусков не много, средними и медианами эти пропуски заполнить не получиться. Оставим их "As is"

# %% [markdown]
# #### Пропуски в столбце 'genre'
# Заменим жанр на "NoGenre"

# %%
games['genre'].fillna('NoGenre', inplace=True)

# %% [markdown]
# #### Пропуски в столбцах 'critic_score' и 'user_score'
# Причины отсутствия рейтинга не известны.
# Могут быть и нулевой рейтинг и чтобы не смешивать пропуски с нулевым рейтингом, пропуски заполним значением -1

# %%
games['critic_score'].fillna(-1, inplace=True)
games['user_score'].fillna(-1, inplace=True)

# %% [markdown]
# #### Пропуски в столбце 'rating'
# ESRB была основана в 1994 году, поэтому у игр выпуска до 1994 рейтинга может и не быть.
# Заменим пропуски на "NoRating"

# %% [markdown]
# * Первоначально "K-A" ("Kids to Adults")
# * «EC» («Early childhood») — «Для детей младшего возраста»
# * «RP» («Rating Pending») — «Рейтинг ожидается»
#
# меняем на "E"
#
# * «AO» («Adults Only 18+») — «Только для взрослых»
#
# меняем на "M"

# %%
games['rating'].fillna('NoRating', inplace=True)

# %%
games['rating'].value_counts()
# Out:
# NoRating    6766
# E           3990
# T           2961
# M           1563
# E10+        1420
# EC             8
# RP             3
# K-A            3
# AO             1
# Name: rating, dtype: int64

# %% [markdown]
# Разбераемся с редковстречающимися значениями рейтинга - заменим на более частые аналоги

# %%
games['rating'].replace(to_replace=['EC','RP','K-A'],value='E', inplace=True)
games['rating'].replace('AO','M', inplace=True)

# %% [markdown]
# ### Посчитаем суммарные продажи во всех регионах и запишем их в столбец 'total_sales'

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 12 columns):
# name               16715 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null datetime64[ns]
# genre              16715 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       16715 non-null float64
# user_score         16715 non-null float64
# rating             16715 non-null object
# total_sales        16715 non-null float64
# dtypes: datetime64[ns](1), float64(7), object(4)
# memory usage: 1.5+ MB

# %%
games.head(10)
# Out:
#                         name platform year_of_release         genre  na_sales  \
# 0                 Wii Sports      Wii      2006-01-01        Sports     41.36
# 1          Super Mario Bros.      NES      1985-01-01      Platform     29.08
# 2             Mario Kart Wii      Wii      2008-01-01        Racing     15.68
# 3          Wii Sports Resort      Wii      2009-01-01        Sports     15.61
# 4   Pokemon Red/Pokemon Blue       GB      1996-01-01  Role-Playing     11.27
# 5                     Tetris       GB      1989-01-01        Puzzle     23.20
# 6      New Super Mario Bros.       DS      2006-01-01      Platform     11.28
# 7                   Wii Play      Wii      2006-01-01          Misc     13.96
# 8  New Super Mario Bros. Wii      Wii      2009-01-01      Platform     14.44
# 9                  Duck Hunt      NES      1984-01-01       Shooter     26.93
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score    rating  \
# ...

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# * Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# * Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# * Возьмите данные за соответствующий **актуальный период**. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# * Не учитывайте в работе данные за **предыдущие годы**.
# * Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# * Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# * Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# * Соотнесите выводы с продажами игр на других платформах.
# * Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# ### Посмотрим, сколько игр выпускалось в разные годы

# %%
plt.figure(figsize=(10, 6))
games['year_of_release'].dt.year.plot(kind='hist', bins=37);
plt.grid(True)
plt.xlabel('Год выпуска')
plt.ylabel('Кроличество релизов')
plt.title('Распределение релизов по годам')
plt.show()

# %% [markdown]
# Первые игры появились в 80-ых годах. Далее с 94 наблюдается стабильный рост, резкий скачок происходит в 2002 году. Пик релизов приходится на 2008-2009 года, далее наблюдается спад релизов игр.

# %% [markdown]
# ### Продажи по платформам

# %%
games.groupby('platform').agg({'total_sales':'sum'}).sort_values(by='total_sales', ascending=False).head(15)
# Out:
#           total_sales
# platform
# PS2           1255.77
# X360           971.42
# PS3            939.65
# Wii            907.51
# DS             806.12
# PS             730.86
# GBA            317.85
# PS4            314.14
# PSP            294.05
# PC             259.52
# 3DS            259.00
# XB             257.74
# GB             255.46
# NES            251.05
# N64            218.68

# %% [markdown]
# Выберем 6 платформ с наибольшими суммарными продажами. Разница между 6 и 7 местом по продажам отличается более чем в 2 раза

# %%
top = games.groupby('platform').agg({'total_sales':'sum'}).sort_values(by='total_sales', ascending=False).head(6)
top.reset_index(inplace=True)
top.columns = ['platform', 'total_sales']

toplist = top['platform'].tolist()
toplist
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %%
ax = None
legend_list = []
for platform in toplist:
    ax = games.query('platform == @platform').groupby('year_of_release').agg({'total_sales':'sum'}).plot(style='o-', ax=ax, label=platform,  figsize=(17, 10))
    legend_list.append(platform)
plt.xlabel("Год выпуска") 
plt.ylabel("Количество проданных игр (млн копии)")
plt.title('Суммарные продажи игр (млн копии)')
ax.grid(True) 
ax.legend(legend_list)    
plt.show()

# %%
games.query('platform == "DS" & year_of_release == "1985"')
# Out:
#                                       name platform year_of_release   genre  \
# 15957  Strongest Tokyo University Shogi DS       DS      1985-01-01  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15957       0.0       0.0      0.02          0.0          -1.0        -1.0
#
#          rating  total_sales
# 15957  NoRating         0.02

# %% [markdown]
# Срок "жизни" консолей
#
# * PS - с 1994 по 2004
# * PS2 - с 2000 по 2011
# * DS - с 2004 по 2013 (возможно что игру 1985 ошибочно приписали к "DS")
# * X360 - с 2005 по 2016("настоящее время")
# * PS3 - с 2006 по 2016("настоящее время")
# * Wii - с 2006 по 2016("настоящее время")
#
# Выходит, что среднее время жизни консолей около 10 лет

# %% [markdown]
# Рассмотрим данные за последние 3 года (с 2013 года)
#
# в 2013 году появились новые платформы PS4 и XOne актуальные в 2016 году и будут продаваться в 2017 году

# %% [markdown]
# ### Динамика продаж

# %%
games_query = games.query('year_of_release >= 2013')
platforms_query = games_query['platform'].unique().tolist()
platforms_query
# Out:
# ['PS3', 'X360', 'PS4', '3DS', 'XOne', 'WiiU', 'Wii', 'PC', 'PSV', 'DS', 'PSP']

# %%
ax = None
legend_list = []
for platform in platforms_query:
    ax = games_query.query('platform == @platform').groupby('year_of_release').agg({'total_sales':'sum'}).plot(style='o-', ax=ax,figsize=(17, 15))
    legend_list.append(platform)
plt.title('Суммарные продажи игр (млн копии)')
ax.grid(True)
plt.xlabel('Год релиза', fontsize=14)
plt.ylabel("Количество проданных игр (млн копии)")
ax.legend(legend_list, fontsize=14)    
plt.show()

# %%
ax = None
legend_list = []
for platform in ["PS4", "XOne", "3DS", "WiiU", "PSV", 'PS3']:
    ax = games.query('platform == @platform').groupby('year_of_release').agg({'total_sales':'sum'}).plot(style='o-', ax=ax,figsize=(17, 10))
    legend_list.append(platform)
plt.title('Суммарные продажи игр (млн копии)')
ax.grid(True)
plt.xlabel('Год релиза')
plt.ylabel("Количество проданных игр (млн копии)")
ax.legend(legend_list, fontsize=14)    
plt.show()

# %%
ax = None
legend_list = []
for platform in ["PS4", "XOne", "3DS", "WiiU", "PSV"]:
    ax = games.query('platform == @platform').groupby('year_of_release').agg({'total_sales':'count'}).plot(style='o-', ax=ax,figsize=(17, 10))
    legend_list.append(platform)
plt.title('Количество релизов')
ax.grid(True)
plt.xlabel('Год релиза', fontsize=14)
plt.ylabel("Количество проданных игр (млн копии)")
ax.legend(legend_list, fontsize=14)    
plt.show()

# %% [markdown]
# На конец 2016 года лидируют по продажам следующие платформы:
#
# 1. PS4
# 2. Xone
# 3. 3DS
#
# Количество релизов на платформах "PS4", "XOne" растет, но суммарные продажи на всех платформах снижаются.

# %% [markdown]
# ### График «ящик с усами» по глобальным продажам игр

# %%
games_query['total_sales'].describe()
# Out:
# count    2233.000000
# mean        0.488442
# std         1.235226
# min         0.010000
# 25%         0.030000
# 50%         0.110000
# 75%         0.400000
# max        21.050000
# Name: total_sales, dtype: float64

# %%
games.boxplot('total_sales', figsize=(8, 8)).set_ylim(0, 2.5);

# %% [markdown]
# В среднем продажи составляют до 1,2 млн копий, медиана - 0,17 млн.

# %%
platform_new = ['PS4', 'XOne', '3DS']

# %%
ax = games_query.query("platform in @platform_new").boxplot(column='total_sales', by='platform', fontsize=14, figsize=(16,8))
ax.set_xlabel('Платформа', fontsize=14)
ax.set_title('Вохplot по платформам')
ax.set_ylim(0, 2.5)
# Out:
# (0, 2.5)

# %%
games_query.query("platform in @platform_new").groupby('platform')['total_sales'].describe()
# Out:
#           count      mean       std   min   25%   50%    75%    max
# platform
# 3DS       303.0  0.472772  1.381347  0.01  0.04  0.09  0.280  14.60
# PS4       392.0  0.801378  1.609456  0.01  0.06  0.20  0.730  14.63
# XOne      247.0  0.645020  1.036139  0.01  0.06  0.22  0.685   7.39

# %% [markdown]
# Платформы PS4 и XOne имею очень близке показатели продаж (медиана 0,20-0,22, верхняя граница продаж - 1.6-1,7 млн копий).
#
# У 3DS верхняя граница продаж около 300 тыс копий

# %%
ax = None
legend_list = []
for platform in platforms_query:
    
    ax = games_query.query('platform == @platform').groupby('year_of_release').agg({'total_sales':'sum'}).plot(style='o-', ax=ax, label=platform,  figsize=(17, 10))
    legend_list.append(platform)

plt.title('Суммарные продажи игр  (млн копии)')
ax.grid(True) 
plt.ylabel("Количество проданных игр (млн копии)")
plt.xlabel("Год выпуска")
ax.legend(legend_list)    
plt.show()

# %% [markdown]
# ###  Влияние отзывов пользователей и критиков  на продажи

# %% [markdown]
# ####  Влияние отзывов критиков на продажи

# %%
games_ps3 = games[(games['platform'] == 'PS3') & (games['critic_score'] > 0)]
games_ps3.plot(x='critic_score', y='total_sales', kind='scatter',figsize = (10,6), 
                title = 'Зависимость суммарных продаж игр PS3 от отзывов критиков', alpha=0.8)
plt.ylabel("Количество продаж (млн копии)")
plt.xlabel("Оценка критиков");

# %%
games_x360 = games[(games['platform'] == 'X360') & (games['critic_score'] > 0)]
games_x360.plot(x='critic_score', y='total_sales', kind='scatter',figsize = (10,6), 
                title = 'Зависимость суммарных продаж игр X360 от отзывов критиков', alpha=0.8)
plt.ylabel("Количество продаж (млн копии)")
plt.xlabel("Оценка критиков");

# %% [markdown]
# С увеличением оценки критиков, увеличивается количество продаж игр

# %% [markdown]
# Коэффициент корреляции количества продаж от отзывов критиков для платформ PS3 и X360

# %%
print("Коэффициент корреляция для PS3", games_ps3['total_sales'].corr(games_ps3['critic_score']))
print("Коэффициент корреляция для X360", games_x360['total_sales'].corr(games_x360['critic_score']))
# Out:
# Коэффициент корреляция для PS3 0.43243156856420606
# Коэффициент корреляция для X360 0.3937358653072588

# %% [markdown]
# ####   Влияние отзывов пользователей на продажи

# %%
games_ps3_users = games[(games['platform'] == 'PS3') & (games['user_score'] > 0)]
games_ps3_users.plot(x='user_score', y='total_sales', kind='scatter',figsize = (10,6), 
                title = 'Зависимость суммарных продаж игр PS3 от отзывов пользователей', alpha=0.8)
plt.ylabel("Количество продаж (млн копии)")
plt.xlabel("Оценка пользователей");

# %%
games_x360_users = games[(games['platform'] == 'X360') & (games['user_score'] > 0)]
games_x360_users.plot(x='user_score', y='total_sales', kind='scatter',figsize = (10,6), 
                title = 'Зависимость суммарных продаж игр X360 от отзывов пользователей', alpha=0.8)
plt.ylabel("Количество продаж (млн копии)")
plt.xlabel("Оценка пользователей");

# %%
print("Коэффициент корреляция для PS3", games_ps3_users['total_sales'].corr(games_ps3_users['user_score']))
print("Коэффициент корреляция для X360", games_x360_users['total_sales'].corr(games_x360_users['user_score']))
# Out:
# Коэффициент корреляция для PS3 0.12669133936341712
# Коэффициент корреляция для X360 0.11445882978454186

# %% [markdown]
# С увеличением оценки пользователей увеличивается, как и с оценками критиков, количество продаж игр, но имеется большее количество выбросов

# %% [markdown]
# #### Посмотрим  корреляцию между отзывами и продажами

# %% [markdown]
# Посмотрим корреляцию на платформе PS4

# %%
games_filtered = games.query('critic_score > 0 & user_score > 0')[['platform', 'total_sales', 'critic_score', 'user_score']]
games_ps3_corr = games_filtered[(games_filtered['platform'] == 'PS3')]                                                                
games_ps3_corr.corr().round(3)
# Out:
#               total_sales  critic_score  user_score
# total_sales         1.000         0.428       0.143
# critic_score        0.428         1.000       0.629
# user_score          0.143         0.629       1.000

# %%
plt.figure(figsize=(5,5))
sns.heatmap(games_ps3_corr.corr(), annot=True, cmap="coolwarm", fmt='.2f');

# %% [markdown]
# На продажи сильнее всего оценка критиков, оценка пользователей влияние почти не оказывает

# %%
fig, axes = plt.subplots(len(toplist), 1, figsize=(5,25))

for i in range(len(toplist)):
    platform = toplist[i]
    corr = games_filtered.query('platform == @platform')
    ax = sns.heatmap(corr.corr(), annot=True, cmap="coolwarm", fmt='.2f', ax=axes[i]);
    ax.set_title(platform, fontsize=12)

# %% [markdown]
# Данные по ко корреляции совпадают с предыдущими выводами.

# %% [markdown]
# ###  Общее распределение игр по жанрам

# %%
games_query.groupby('genre').agg({'total_sales': 'sum'}).sort_values(by='total_sales', ascending=False).plot(kind='bar', fontsize=12, figsize=(17,8), grid=True)
plt.xlabel("Жанры игр")
plt.ylabel("Количество продаж (млн копии)");

# %% [markdown]
# Самые прибыльные жанры:
# 1. Action
# 2. Shooters
# 3. Sports
#
# Меньше всего прибыли приносят:
# 1. Puzle
# 2. Strategy
# 3. Simulation

# %% [markdown]
# ## Составляем портрет пользователя каждого региона

# %% [markdown]
# Определите для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# * Самые популярные жанры (топ-5). Поясните разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# ### Самые популярные платформы (топ-5)

# %%
games.groupby(by='platform').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar');
plt.xlabel("Популярные платформы в Северной Америке")
plt.ylabel("Количество продаж (млн копии)")
games.groupby(by='platform').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar');
plt.xlabel("Популярные платформы в Европе")
plt.ylabel("Количество продаж (млн копии)")
games.groupby(by='platform').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar');
plt.xlabel("Популярные платформы в Японии")
plt.ylabel("Количество продаж (млн копии)")
games.groupby(by='platform').agg({'total_sales':'sum', 'na_sales':'sum', 'eu_sales':'sum', 'jp_sales':'sum'}).sort_values(by='total_sales', ascending=False).head(10).plot(kind='bar', figsize=(15,6))
plt.xlabel("Платформы")
plt.ylabel("Количество продаж (млн копии)")
# Out:
# Text(0, 0.5, 'Количество продаж (млн копии)')

# %% [markdown]
# В Северной Америке на 1 и 2 местах приставки X360 и PS2. Далее идет Wii и замыкает топ-5 - PS3 и DS.
#
# В Европе 1-2 места в топ-5 занимают PS2 и PS3, далее X360, Wii и PS.
#
# В Японии на 1 месте - DS, на 2-3 месте PS и PS2, замыкают топ-5 SNES и 3DS.

# %% [markdown]
# ### Самые популярные жанры (топ-5)

# %%
games.groupby(by='genre').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar');
plt.xlabel("Популярные жанры игр в Северной Америке")
plt.ylabel("Количество продаж (млн копии)")
games.groupby(by='genre').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar');
plt.xlabel("Популярные жанры игр в Европе")
plt.ylabel("Количество продаж (млн копии)")
games.groupby(by='genre').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar');
plt.xlabel("Популярные жанры игр в Японии")
plt.ylabel("Количество продаж (млн копии)")
games.groupby(by='genre').agg({'total_sales':'sum', 'na_sales':'sum', 'eu_sales':'sum', 'jp_sales':'sum'}).sort_values(by='total_sales', ascending=False).head(7).plot(kind='bar', figsize=(15,6));
plt.xlabel("Популярные жанры игр")
plt.ylabel("Количество продаж (млн копии)");

# %% [markdown]
# В Северной Америке и Европе предпочтенния совпадают (Action, Sports, Shooter)
#
# В Японии предпочитают Role-Playing, далее идут Action и Sport

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи

# %% [markdown]
# ESRB была основана в 1994 году
#
# Рейтинг игр ESRB основан на их содержании аналогично рейтинговым системам кинофильмов. Рейтинг игры напечатан на упаковке, содержится в её рекламе и указан на сайте игры.
#
# * «EC» («Early childhood») — «Для детей младшего возраста»
# * «E» («Everyone») — «Для всех»
# * «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# * «T» («Teen») — «Подросткам»
# * «M» («Mature») — «Для взрослых»
# * «AO» («Adults Only 18+») — «Только для взрослых»
# * «RP» («Rating Pending») — «Рейтинг ожидается»

# %%
games.query('rating != "NoRating"').groupby(by='rating').agg({'na_sales':'sum', 'eu_sales':'sum', 'jp_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar')
plt.xlabel("ESRB рейтинг игр в Северной Америке")
plt.ylabel("Количество продаж (млн копии)")
games.query('rating != "NoRating"').groupby(by='rating').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar')
plt.xlabel("ESRB рейтинг игр в Европе")
plt.ylabel("Количество продаж (млн копии)")
games.query('rating != "NoRating"').groupby(by='rating').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar')
plt.xlabel("ESRB рейтинг игр в Японии")
plt.ylabel("Количество продаж (млн копии)")
games.query('rating != "NoRating"').groupby(by='rating').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar')
plt.xlabel("ESRB рейтинг игр")
plt.ylabel("Количество продаж (млн копии)");

# %% [markdown]
# Отбросим игры без рейтинга
#
# В Америке и в Европе предпочитают игры с рейтингом «E» («Everyone») — «Для всех», далее с примерно с равными продажами идут игры «T» — «Подросткам» и «M» — «Для взрослых»
#
# В Японии на 1 месте также игры с рейтингом «E» («Everyone») — «Для всех», на 2 месте игры с рейтингом «T» — «Подросткам»

# %% [markdown]
# ## Проверяем гипотезы

# %% [markdown]
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
# * Как вы сформулировали нулевую и альтернативную гипотезы;
# * Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# Для проверки обеих гипотез будем использовать t-критерий Стьюдента, т.к. в обоих случаях выборки независимы между собой.
#
# Задаем пороговое значение **alpha = 0.05**

# %%
alpha = 0.05

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# **Сформулируем гипотезы**
#
# * Н0: средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# * H1: средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой

# %%
xone_ratings = games[(games['platform'] == 'XOne') & (games['user_score'] > 0)]['user_score']
pc_ratings = games[(games['platform'] == 'PC') & (games['user_score'] > 0)]['user_score']

# %% [markdown]
# Расчет p-value:
#
# Т.к. выборки у нас независимые, воспользуемся функцией ttest_ind

# %%
results = st.ttest_ind(xone_ratings, pc_ratings)
print('Cредние пользовательские рейтинги платформы Xbox One {:.2f}'.format(xone_ratings.mean()))
print('Cредние пользовательские рейтинги платформы PC {:.2f}\n'.format(pc_ratings.mean()))
print('p-значение: {:.6f}'. format(results.pvalue))

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Cредние пользовательские рейтинги платформы Xbox One 6.52
# Cредние пользовательские рейтинги платформы PC 7.06
#
# p-значение: 0.000014
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Нулевую гипотезу отвергаем.**
#
# **Верно утверждение**, что средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой
#
# Cредние пользовательские рейтинги платформы **PC** выше чем для платформы **Xbox One**

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# **Сформулируем гипотезы:**
#
# * H0: средние пользовательские рейтинги жанров Action и Sports одинаковые
# * H1: средние пользовательские рейтинги жанров Action и Sports разные

# %%
action_ratings = games[(games['genre'] == 'Action') & (games['user_score'] > 0)]['user_score']
sports_ratings = games[(games['genre'] == 'Sports') & (games['user_score'] > 0)]['user_score']

# %%
results = st.ttest_ind(action_ratings, sports_ratings)
print('Cредние пользовательские рейтинги для жанра Action {:.2f}'.format(action_ratings.mean()))
print('Cредние пользовательские рейтинги для жанра Sports {:.2f}\n'.format(sports_ratings.mean()))
print('p-значение: {:.6f}'. format(results.pvalue))

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Cредние пользовательские рейтинги для жанра Action 7.05
# Cредние пользовательские рейтинги для жанра Sports 6.96
#
# p-значение: 0.104070
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Нулевую гипотезу отвергнуть не получилось.**
#
# **Подверждается гипотеза**, что средние пользовательские рейтинги жанров Action и Sports одинаковые

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# По проведенному анализу видно, что рынок игр падает. После пика в 2008-2009 годах, когда ежегодное количество релизов превышало 1400 ежегодно, сейчас идет спад. На текущий наблюдается около 500-600 релизов игр ежегодно. На новых платформах(PS4 и XOne) количество релизов растет, но общее количество продаж на всех платфомах падает.
#
# Наблюдаем что среднее время жизни игровой платформы около 10 лет.
# И на смену популярным платформам PS3 и X360, пришла замена PS4 и XOne
#
# На продажи больше влияют отзывы критиков, отзывы пользователей на количество продаж практически не сказываются. Пользователи решая купить игру обращают внимание на оценки критиков, а не отзывы пользователей
#
# Action, Shooters, Sports - жанры которые приносящие наибольшую прибыль, меньше всего приносят прибыль: Puzle, Strategy и Simulation
#
# Предпочтения по платформам в Европе и Америке практически совпадают, там предпочитают PS3, PS2 и X360.
# В Японии предпочтения отдают Nintendo DS, далее PS и PS2.
#
# В игровых жанрах Северная Америка и Европа тоже совпадают (Action, Sports, Shooter).
# Тогда как в Японии предпочитают Role-Playing, далее с 2-х кратным отсаванием идут жанры Action и Sport
#
# Пользователи в мире предпочитают игры с рейтингом «E» «Для всех», во всех странах игры с этим рейтингом идут на 1 месте.
# В Северной Америке 2 и 3 места делят игры для «Подростков» и «Для взрослых». В Японии незначительно отставая от 1 места идут игры для «Подростков», на 3 месте - «Для взрослых».
